# %%
import pandas as pd

# %%
bhousing=pd.read_csv(r"C:\Users\jonat\OneDrive\Desktop\TTU Stuff\Fall\Big Data Strat\NoteBookFiles\Module 7\Bhousing(1).csv")

# %%
Car=pd.read_csv(r"C:\Users\jonat\OneDrive\Desktop\TTU Stuff\Fall\Big Data Strat\NoteBookFiles\Module 7\Car.csv")

# %%
Diabetes=pd.read_csv(r"C:\Users\jonat\OneDrive\Desktop\TTU Stuff\Fall\Big Data Strat\NoteBookFiles\Module 7\Diabetes.csv")

# %%
Wine=pd.read_csv(r"C:\Users\jonat\OneDrive\Desktop\TTU Stuff\Fall\Big Data Strat\NoteBookFiles\Module 7\Wine.csv")

# %%
import statsmodels.api as sm

# %%
medvVersusRoomsModel=sm.OLS(bhousing.MEDV,bhousing.RM)
result=medvVersusRoomsModel.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.901
# Model:                            OLS   Adj. R-squared (uncentered):              0.901
# Method:                 Least Squares   F-statistic:                              4614.
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   3.77e-256
# Time:                        14:30:34   Log-Likelihood:                         -1747.1
# No. Observations:                 506   AIC:                                      3496.
# Df Residuals:                     505   BIC:                                      3500.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
medvVersusRoomsModel=sm.OLS(bhousing.MEDV,sm.add_constant(bhousing.RM))
result=medvVersusRoomsModel.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.484
# Model:                            OLS   Adj. R-squared:                  0.482
# Method:                 Least Squares   F-statistic:                     471.8
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):           2.50e-74
# Time:                        14:30:09   Log-Likelihood:                -1673.1
# No. Observations:                 506   AIC:                             3350.
# Df Residuals:                     504   BIC:                             3359.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -34.6705      2.650    -13.084      0.000     -39.877     -29.464
# ...

# %%
medvVersusRoomsModel=sm.OLS(bhousing.MEDV,sm.add_constant(bhousing.ZN))
result=medvVersusRoomsModel.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.130
# Model:                            OLS   Adj. R-squared:                  0.128
# Method:                 Least Squares   F-statistic:                     75.26
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):           5.70e-17
# Time:                        14:31:02   Log-Likelihood:                -1805.0
# No. Observations:                 506   AIC:                             3614.
# Df Residuals:                     504   BIC:                             3623.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         20.9173      0.425     49.247      0.000      20.083      21.752
# ...

# %%
medvVersusRoomsModel=sm.OLS(bhousing.MEDV,bhousing.PTRATIO)
result=medvVersusRoomsModel.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.805
# Model:                            OLS   Adj. R-squared (uncentered):              0.805
# Method:                 Least Squares   F-statistic:                              2088.
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   1.52e-181
# Time:                        14:32:28   Log-Likelihood:                         -1919.1
# No. Observations:                 506   AIC:                                      3840.
# Df Residuals:                     505   BIC:                                      3844.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
Y=bhousing.MEDV
X=bhousing[['CRIM',"ZN","INDUS","CHAS"]]
medvModel=sm.OLS(Y,X)
result=medvModel.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.708
# Model:                            OLS   Adj. R-squared (uncentered):              0.706
# Method:                 Least Squares   F-statistic:                              304.4
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   1.06e-132
# Time:                        14:41:14   Log-Likelihood:                         -2021.5
# No. Observations:                 506   AIC:                                      4051.
# Df Residuals:                     502   BIC:                                      4068.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
Y=bhousing.MEDV
X=bhousing[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'LSTAT']]
medvModel=sm.OLS(Y,X)
result=medvModel.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.957
# Model:                            OLS   Adj. R-squared (uncentered):              0.956
# Method:                 Least Squares   F-statistic:                              908.6
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        14:47:52   Log-Likelihood:                         -1539.0
# No. Observations:                 506   AIC:                                      3102.
# Df Residuals:                     494   BIC:                                      3153.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
Y=bhousing.MEDV
X=bhousing[['CRIM', 'ZN', 'INDUS', 'CHAS', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'LSTAT']]
medvModel=sm.OLS(Y,X)
result=medvModel.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.957
# Model:                            OLS   Adj. R-squared (uncentered):              0.956
# Method:                 Least Squares   F-statistic:                              993.1
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        14:54:19   Log-Likelihood:                         -1539.0
# No. Observations:                 506   AIC:                                      3100.
# Df Residuals:                     495   BIC:                                      3147.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
Y=bhousing.MEDV
X=bhousing[['CRIM', 'ZN', 'INDUS', 'CHAS', 'RM', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'LSTAT']]
medvModel=sm.OLS(Y,X)
result=medvModel.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.957
# Model:                            OLS   Adj. R-squared (uncentered):              0.956
# Method:                 Least Squares   F-statistic:                              1094.
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        14:55:39   Log-Likelihood:                         -1539.1
# No. Observations:                 506   AIC:                                      3098.
# Df Residuals:                     496   BIC:                                      3140.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
Y=bhousing.MEDV
X=bhousing[['CRIM', 'ZN', 'CHAS', 'RM', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'LSTAT']]
medvModel=sm.OLS(Y,X)
result=medvModel.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.957
# Model:                            OLS   Adj. R-squared (uncentered):              0.956
# Method:                 Least Squares   F-statistic:                              1218.
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        14:56:23   Log-Likelihood:                         -1539.2
# No. Observations:                 506   AIC:                                      3096.
# Df Residuals:                     497   BIC:                                      3134.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
bhousingCorr=bhousing.corr()
round(bhousingCorr,2)
# Out:
#          CRIM    ZN  INDUS  CHAS   NOX    RM   AGE   DIS   RAD   TAX  PTRATIO  \
# CRIM     1.00 -0.20   0.41 -0.06  0.42 -0.22  0.35 -0.38  0.63  0.58     0.29
# ZN      -0.20  1.00  -0.53 -0.04 -0.52  0.31 -0.57  0.66 -0.31 -0.31    -0.39
# INDUS    0.41 -0.53   1.00  0.06  0.76 -0.39  0.64 -0.71  0.60  0.72     0.38
# CHAS    -0.06 -0.04   0.06  1.00  0.09  0.09  0.09 -0.10 -0.01 -0.04    -0.12
# NOX      0.42 -0.52   0.76  0.09  1.00 -0.30  0.73 -0.77  0.61  0.67     0.19
# RM      -0.22  0.31  -0.39  0.09 -0.30  1.00 -0.24  0.21 -0.21 -0.29    -0.36
# AGE      0.35 -0.57   0.64  0.09  0.73 -0.24  1.00 -0.75  0.46  0.51     0.26
# DIS     -0.38  0.66  -0.71 -0.10 -0.77  0.21 -0.75  1.00 -0.49 -0.53    -0.23
# RAD      0.63 -0.31   0.60 -0.01  0.61 -0.21  0.46 -0.49  1.00  0.91     0.46
# TAX      0.58 -0.31   0.72 -0.04  0.67 -0.29  0.51 -0.53  0.91  1.00     0.46
# PTRATIO  0.29 -0.39   0.38 -0.12  0.19 -0.36  0.26 -0.23  0.46  0.46     1.00
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
variables=result.model.exog
vif=[variance_inflation_factor(variables,i) for i in range(variables.shape[1])]
vif
# Out:
# [2.068558642102146,
#  2.7399841334230493,
#  1.1191151563881152,
#  44.774278129179166,
#  10.702550982236655,
#  13.326823967608716,
#  43.5878665399207,
#  77.1273951132758,
#  7.788457599440846]

# %%
Y=bhousing.MEDV
X=bhousing[['CRIM', 'ZN', 'CHAS', 'RM', 'DIS', 'RAD', 'TAX',
       'LSTAT']]
medvModel=sm.OLS(Y,X)
result=medvModel.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.956
# Model:                            OLS   Adj. R-squared (uncentered):              0.955
# Method:                 Least Squares   F-statistic:                              1359.
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        15:13:40   Log-Likelihood:                         -1541.7
# No. Observations:                 506   AIC:                                      3099.
# Df Residuals:                     498   BIC:                                      3133.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
variables=result.model.exog
vif=[variance_inflation_factor(variables,i) for i in range(variables.shape[1])]
vif
# Out:
# [2.068091453820564,
#  2.2617168531738616,
#  1.1147500073522614,
#  19.407593308685094,
#  8.46249548399875,
#  13.259635273553883,
#  39.39833607667787,
#  6.474431234813929]

# %%
Y=bhousing.MEDV
X=bhousing[['CRIM', 'ZN', 'CHAS', 'RM', 'DIS', 'RAD',
       'LSTAT']]
medvModel=sm.OLS(Y,X)
result=medvModel.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.955
# Model:                            OLS   Adj. R-squared (uncentered):              0.954
# Method:                 Least Squares   F-statistic:                              1507.
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        15:14:08   Log-Likelihood:                         -1549.5
# No. Observations:                 506   AIC:                                      3113.
# Df Residuals:                     499   BIC:                                      3143.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
variables=result.model.exog
vif=[variance_inflation_factor(variables,i) for i in range(variables.shape[1])]
vif
# Out:
# [2.0621827662142174,
#  2.254764072883299,
#  1.1093747819871922,
#  11.760252351938549,
#  8.421838778469064,
#  4.298664785507666,
#  5.149899422528698]

# %%
Y=bhousing.MEDV
X=bhousing[['CRIM', 'ZN', 'CHAS', 'DIS', 'RAD',
       'LSTAT']]
medvModel=sm.OLS(Y,X)
result=medvModel.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.793
# Model:                            OLS   Adj. R-squared (uncentered):              0.790
# Method:                 Least Squares   F-statistic:                              319.1
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   2.17e-167
# Time:                        15:14:32   Log-Likelihood:                         -1934.7
# No. Observations:                 506   AIC:                                      3881.
# Df Residuals:                     500   BIC:                                      3907.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
variables=result.model.exog
vif=[variance_inflation_factor(variables,i) for i in range(variables.shape[1])]
vif
# Out:
# [2.040521839699013,
#  2.2375337533434214,
#  1.059249264395732,
#  3.9416287324211603,
#  3.738091484464663,
#  4.2485126843488015]

# %%
Y=bhousing.MEDV
X=bhousing[['CRIM', 'ZN', 'CHAS', 'RM', 'DIS', 'RAD',
        'LSTAT']]
medvModel=sm.OLS(Y,X)
result=medvModel.fit()
result.summary()

# %%
import numpy as np

# %%
bhousing['log_CRIM']=np.log(bhousing.CRIM)
bhousing['log_MEDV']=np.log(bhousing.MEDV)

# %%
Y=bhousing.log_MEDV
X=bhousing[['log_CRIM','ZN','CHAS','DIS','RAD','LSTAT']]
medvModel=sm.OLS(Y,X)
result=medvModel.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:               log_MEDV   R-squared (uncentered):                   0.929
# Model:                            OLS   Adj. R-squared (uncentered):              0.928
# Method:                 Least Squares   F-statistic:                              1082.
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   1.00e-282
# Time:                        15:29:39   Log-Likelihood:                         -616.75
# No. Observations:                 506   AIC:                                      1246.
# Df Residuals:                     500   BIC:                                      1271.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
X=Wine[['Alcohol',"Malic_acid","Ash"]]
Y=Wine.Class
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Class   R-squared (uncentered):                   0.880
# Model:                            OLS   Adj. R-squared (uncentered):              0.878
# Method:                 Least Squares   F-statistic:                              426.0
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                    3.66e-80
# Time:                        15:48:13   Log-Likelihood:                         -195.12
# No. Observations:                 178   AIC:                                      396.2
# Df Residuals:                     175   BIC:                                      405.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
Wine.columns
# Out:
# Index(['Class', 'Alcohol', 'Malic_acid', 'Ash', 'Alcalinity_Ash', 'Magnesium',
#        'Total_phenols', 'Flavanoids', 'Noflavanoid_phenols', 'Proanthocyanins',
#        'Color_intensity', 'Hue', 'OD280', 'Proline'],
#       dtype='object')

# %%
X=Wine[[ 'Alcohol', 'Malic_acid', 'Ash', 'Alcalinity_Ash', 'Magnesium',
       'Total_phenols', 'Flavanoids', 'Noflavanoid_phenols', 'Proanthocyanins',
       'Color_intensity', 'Hue', 'OD280', 'Proline']]
Y=Wine.Class
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Class   R-squared (uncentered):                   0.980
# Model:                            OLS   Adj. R-squared (uncentered):              0.978
# Method:                 Least Squares   F-statistic:                              607.6
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   5.95e-132
# Time:                        15:48:57   Log-Likelihood:                         -37.353
# No. Observations:                 178   AIC:                                      100.7
# Df Residuals:                     165   BIC:                                      142.1
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
X=Wine[[ 'Alcohol', 'Malic_acid', 'Ash', 'Alcalinity_Ash', 'Magnesium',
       'Total_phenols', 'Flavanoids', 'Proanthocyanins',
       'Color_intensity', 'Hue', 'OD280', 'Proline']]
Y=Wine.Class
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Class   R-squared (uncentered):                   0.980
# Model:                            OLS   Adj. R-squared (uncentered):              0.978
# Method:                 Least Squares   F-statistic:                              662.3
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   2.26e-133
# Time:                        15:49:34   Log-Likelihood:                         -37.353
# No. Observations:                 178   AIC:                                      98.71
# Df Residuals:                     166   BIC:                                      136.9
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
X=Wine[[ 'Alcohol', 'Malic_acid', 'Ash', 'Alcalinity_Ash', 'Magnesium',
       'Total_phenols', 'Flavanoids', 'Proanthocyanins',
       'Color_intensity', 'OD280', 'Proline']]
Y=Wine.Class
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Class   R-squared (uncentered):                   0.979
# Model:                            OLS   Adj. R-squared (uncentered):              0.978
# Method:                 Least Squares   F-statistic:                              724.7
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   1.04e-134
# Time:                        15:49:52   Log-Likelihood:                         -37.605
# No. Observations:                 178   AIC:                                      97.21
# Df Residuals:                     167   BIC:                                      132.2
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
X=Wine[[ 'Alcohol', 'Ash', 'Alcalinity_Ash', 'Magnesium',
       'Total_phenols', 'Flavanoids', 'Proanthocyanins',
       'Color_intensity', 'OD280', 'Proline']]
Y=Wine.Class
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Class   R-squared (uncentered):                   0.979
# Model:                            OLS   Adj. R-squared (uncentered):              0.978
# Method:                 Least Squares   F-statistic:                              800.4
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   4.19e-136
# Time:                        15:50:07   Log-Likelihood:                         -37.774
# No. Observations:                 178   AIC:                                      95.55
# Df Residuals:                     168   BIC:                                      127.4
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
X=Wine[[ 'Alcohol', 'Alcalinity_Ash', 'Magnesium',
       'Total_phenols', 'Flavanoids', 'Proanthocyanins',
       'Color_intensity', 'OD280', 'Proline']]
Y=Wine.Class
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Class   R-squared (uncentered):                   0.979
# Model:                            OLS   Adj. R-squared (uncentered):              0.978
# Method:                 Least Squares   F-statistic:                              889.5
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   2.20e-137
# Time:                        15:50:34   Log-Likelihood:                         -38.280
# No. Observations:                 178   AIC:                                      94.56
# Df Residuals:                     169   BIC:                                      123.2
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
X=Wine[[ 'Alcohol', 'Alcalinity_Ash',
       'Total_phenols', 'Flavanoids', 'Proanthocyanins',
       'Color_intensity', 'OD280', 'Proline']]
Y=Wine.Class
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Class   R-squared (uncentered):                   0.979
# Model:                            OLS   Adj. R-squared (uncentered):              0.978
# Method:                 Least Squares   F-statistic:                              996.1
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   1.60e-138
# Time:                        15:50:52   Log-Likelihood:                         -39.190
# No. Observations:                 178   AIC:                                      94.38
# Df Residuals:                     170   BIC:                                      119.8
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
variables=result.model.exog
vif=[variance_inflation_factor(variables,i) for i in range(variables.shape[1])]
vif
# Out:
# [110.4577059265988,
#  37.706981793012105,
#  62.235289203037205,
#  30.720227212350643,
#  15.73832736803663,
#  12.184911821288324,
#  52.88948421362695,
#  14.504439197941615]

# %%
X=Wine[['Alcalinity_Ash',
       'Total_phenols', 'Flavanoids', 'Proanthocyanins',
       'Color_intensity', 'OD280', 'Proline']]
Y=Wine.Class
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Class   R-squared (uncentered):                   0.968
# Model:                            OLS   Adj. R-squared (uncentered):              0.967
# Method:                 Least Squares   F-statistic:                              751.0
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   8.07e-125
# Time:                        15:51:51   Log-Likelihood:                         -75.769
# No. Observations:                 178   AIC:                                      165.5
# Df Residuals:                     171   BIC:                                      187.8
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
variables=result.model.exog
vif=[variance_inflation_factor(variables,i) for i in range(variables.shape[1])]
vif
# Out:
# [20.347637602461017,
#  59.04870674765384,
#  28.300746742998783,
#  15.737066561617729,
#  9.848197596430802,
#  41.94445389987131,
#  12.354234436693691]

# %%
X=Wine[['Alcalinity_Ash', 'Flavanoids', 'Proanthocyanins',
       'Color_intensity', 'OD280', 'Proline']]
Y=Wine.Class
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Class   R-squared (uncentered):                   0.966
# Model:                            OLS   Adj. R-squared (uncentered):              0.965
# Method:                 Least Squares   F-statistic:                              814.1
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   1.89e-123
# Time:                        15:52:25   Log-Likelihood:                         -82.592
# No. Observations:                 178   AIC:                                      177.2
# Df Residuals:                     172   BIC:                                      196.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
variables=result.model.exog
vif=[variance_inflation_factor(variables,i) for i in range(variables.shape[1])]
vif
# Out:
# [18.92797982619066,
#  19.376856654003113,
#  15.51470972264711,
#  9.188869743701977,
#  37.91623748195528,
#  12.150746452435344]

# %%
X=Wine[['Alcalinity_Ash', 'Proanthocyanins',
       'Color_intensity', 'OD280', 'Proline']]
Y=Wine.Class
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Class   R-squared (uncentered):                   0.953
# Model:                            OLS   Adj. R-squared (uncentered):              0.952
# Method:                 Least Squares   F-statistic:                              706.6
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   4.36e-113
# Time:                        15:52:48   Log-Likelihood:                         -110.76
# No. Observations:                 178   AIC:                                      231.5
# Df Residuals:                     173   BIC:                                      247.4
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
variables=result.model.exog
vif=[variance_inflation_factor(variables,i) for i in range(variables.shape[1])]
vif
# Out:
# [15.813858712434424,
#  12.943527190606934,
#  9.176908880459154,
#  24.247827078534062,
#  11.515635503997897]

# %%
X=Wine[['Proanthocyanins',
       'Color_intensity', 'OD280', 'Proline']]
Y=Wine.Class
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Class   R-squared (uncentered):                   0.858
# Model:                            OLS   Adj. R-squared (uncentered):              0.855
# Method:                 Least Squares   F-statistic:                              263.7
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                    1.06e-72
# Time:                        15:53:10   Log-Likelihood:                         -209.53
# No. Observations:                 178   AIC:                                      427.1
# Df Residuals:                     174   BIC:                                      439.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
variables=result.model.exog
vif=[variance_inflation_factor(variables,i) for i in range(variables.shape[1])]
vif
# Out:
# [12.943254174142243, 5.1391266125489, 13.917321932933353, 9.9164582490626]

# %%
X=Wine[['Proanthocyanins',
       'Color_intensity', 'Proline']]
Y=Wine.Class
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Class   R-squared (uncentered):                   0.820
# Model:                            OLS   Adj. R-squared (uncentered):              0.817
# Method:                 Least Squares   F-statistic:                              265.8
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                    6.53e-65
# Time:                        15:53:29   Log-Likelihood:                         -230.87
# No. Observations:                 178   AIC:                                      467.7
# Df Residuals:                     175   BIC:                                      477.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
variables=result.model.exog
vif=[variance_inflation_factor(variables,i) for i in range(variables.shape[1])]
vif
# Out:
# [6.188109686912182, 5.03782940118495, 8.085842662927123]

# %%
Car.columns
# Out:
# Index(['Id', 'Model', 'Price', 'Mfg_Year', 'KM', 'Fuel_Type', 'HP',
#        'Met_Color', 'Color', 'Automatic', 'CC', 'Doors', 'Cylinders', 'Gears',
#        'Quarterly_Tax', 'Weight', 'Mfr_Guarantee', 'BOVAG_Guarantee',
#        'Guarantee_Period', 'ABS', 'Airbag_1', 'Airbag_2', 'Airco',
#        'Automatic_airco', 'Boardcomputer', 'CD_Player', 'Central_Lock',
#        'Powered_Windows', 'Power_Steering', 'Radio', 'Mistlamps',
#        'Sport_Model', 'Backseat_Divider', 'Metallic_Rim', 'Radio_cassette',
#        'Parking_Assistant', 'Tow_Bar'],
#       dtype='object')

# %%
Car.dtypes
# Out:
# Id                    int64
# Model                object
# Price                 int64
# Mfg_Year              int64
# KM                    int64
# Fuel_Type            object
# HP                    int64
# Met_Color             int64
# Color                object
# Automatic             int64
# CC                    int64
# Doors                 int64
# Cylinders             int64
# Gears                 int64
# Quarterly_Tax         int64
# Weight                int64
# Mfr_Guarantee         int64
# BOVAG_Guarantee       int64
# Guarantee_Period      int64
# ABS                   int64
# Airbag_1              int64
# Airbag_2              int64
# Airco                 int64
# Automatic_airco       int64
# Boardcomputer         int64
# CD_Player             int64
# Central_Lock          int64
# Powered_Windows       int64
# Power_Steering        int64
# Radio                 int64
# Mistlamps             int64
# Sport_Model           int64
# Backseat_Divider      int64
# ...

# %%
X=Car[[ 'Mfg_Year', 'KM', 'HP',
       'Met_Color', 'Automatic', 'CC', 'Doors', 'Cylinders', 'Gears',
       'Quarterly_Tax', 'Weight', 'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airbag_1', 'Airbag_2', 'Airco',
       'Automatic_airco', 'Boardcomputer', 'CD_Player', 'Central_Lock',
       'Powered_Windows', 'Power_Steering', 'Radio', 'Mistlamps',
       'Sport_Model', 'Backseat_Divider', 'Metallic_Rim', 'Radio_cassette',
       'Parking_Assistant', 'Tow_Bar']]
Y=Car.Price
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     434.8
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:02:43   Log-Likelihood:                -12112.
# No. Observations:                1436   AIC:                         2.429e+04
# Df Residuals:                    1404   BIC:                         2.446e+04
# Df Model:                          31
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
X=Car[[ 'KM', 'Automatic',
       'Quarterly_Tax', 'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airco',
       'Automatic_airco', 'Boardcomputer', 'CD_Player',
       'Powered_Windows',
       'Sport_Model'
        ]]
Y=Car.Price
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared (uncentered):                   0.960
# Model:                            OLS   Adj. R-squared (uncentered):              0.959
# Method:                 Least Squares   F-statistic:                              2611.
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        16:14:52   Log-Likelihood:                         -13136.
# No. Observations:                1436   AIC:                                  2.630e+04
# Df Residuals:                    1423   BIC:                                  2.637e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
variables=result.model.exog
vif=[variance_inflation_factor(variables,i) for i in range(variables.shape[1])]
vif
# Out:
# [5.298514775198673,
#  1.079643570211266,
#  6.432649125942256,
#  1.896731839119739,
#  7.961429161141945,
#  2.2200995053113943,
#  5.7653032175749575,
#  3.2428656930903483,
#  1.3455337223914152,
#  2.3648342343908317,
#  1.7672373099477583,
#  3.3631153980663524,
#  1.6450950149175487,
#  1.4440376161956012,
#  1.413310878339496]

# %%
Diabetes.columns
# Out:
# Index(['pregnancies', 'glucose', 'diatolic', 'triceps', 'insulin', 'bmi',
#        'dpf', 'age', 'test'],
#       dtype='object')

# %%
Y=Diabetes.test
X=Diabetes[['pregnancies', 'glucose', 'diatolic', 'triceps', 'insulin', 'bmi',
       'dpf', 'age']]
model=sm.Logit(Y,X)
result=model.fit()
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.608498
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                  768
# Model:                          Logit   Df Residuals:                      760
# Method:                           MLE   Df Model:                            7
# Date:                Thu, 09 Nov 2023   Pseudo R-squ.:                 0.05922
# Time:                        16:21:51   Log-Likelihood:                -467.33
# converged:                       True   LL-Null:                       -496.74
# Covariance Type:            nonrobust   LLR p-value:                 2.583e-10
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
Y=Diabetes.test
X=Diabetes[['pregnancies', 'glucose', 'diatolic']]
model=sm.Logit(Y,X)
result=model.fit()
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.613118
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                  768
# Model:                          Logit   Df Residuals:                      765
# Method:                           MLE   Df Model:                            2
# Date:                Thu, 09 Nov 2023   Pseudo R-squ.:                 0.05207
# Time:                        16:26:44   Log-Likelihood:                -470.87
# converged:                       True   LL-Null:                       -496.74
# Covariance Type:            nonrobust   LLR p-value:                 5.835e-12
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
variables=result.model.exog
vif=[variance_inflation_factor(variables,i) for i in range(variables.shape[1])]
vif
# Out:
# [2.37188835416066, 9.155417865821633, 9.168722233458638]
