# %%
import pandas as pd

# %%
Bhousing=pd.read_csv('C:/Users/jonat/OneDrive/Desktop/TTU Stuff/Fall/Big Data Strat/NoteBookFiles/Module 6/Bhousing.csv')
Bhousing
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO  LSTAT  MEDV
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.5
# 2       17.8   4.03  34.7
# ...

# %%
Bhousing.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.5
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
Bhousing.tail(5)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#      LSTAT  MEDV
# 501   9.67  22.4
# 502   9.08  20.6
# 503   5.64  23.9
# 504   6.48  22.0
# 505   7.88  11.9

# %%
Bhousing.shape
# Out:
# (506, 13)

# %%
Bhousing.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
Bhousing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
Bhousing.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.5
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2
# ...

# %%
Bhousing.iloc[5][0]
# Out:
# 0.02985

# %%
Bhousing.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
Bhousing.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.5
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2
# ...

# %%
Bhousing.iloc[5]['AGE']
# Out:
# 58.7

# %%
Bhousing.at[5,"AGE"]=60.7

# %%
Bhousing.iloc[5]['AGE']
# Out:
# 60.7

# %%
Bhousing.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   60.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.5
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2
# ...

# %%
Bhousing2=Bhousing[Bhousing.CRIM>=0.2]

# %%
Bhousing2.head(10)
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 8   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 10  0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 13  0.62976   0.0   8.14     0  0.538  5.949   61.8  4.7075    4  307
# 14  0.63796   0.0   8.14     0  0.538  6.096   84.5  4.4619    4  307
# 15  0.62739   0.0   8.14     0  0.538  5.834   56.5  4.4986    4  307
# 16  1.05393   0.0   8.14     0  0.538  5.935   29.3  4.4986    4  307
# 17  0.78420   0.0   8.14     0  0.538  5.990   81.7  4.2579    4  307
# 18  0.80271   0.0   8.14     0  0.538  5.456   36.6  3.7965    4  307
# 19  0.72580   0.0   8.14     0  0.538  5.727   69.5  3.7965    4  307
# 20  1.25179   0.0   8.14     0  0.538  5.570   98.1  3.7979    4  307
#
#     PTRATIO  LSTAT  MEDV
# 8      15.2  29.93  16.5
# 10     15.2  20.45  15.0
# 13     21.0   8.26  20.4
# 14     21.0  10.26  18.2
# 15     21.0   8.47  19.9
# 16     21.0   6.58  23.1
# ...

# %%
Bhousing3=Bhousing[(Bhousing.CRIM>=.2)&(Bhousing.RM>=5)&(Bhousing.RAD==4)]

# %%
Bhousing3.head(10)
# Out:
#        CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 13  0.62976  0.0   8.14     0  0.538  5.949  61.8  4.7075    4  307     21.0
# 14  0.63796  0.0   8.14     0  0.538  6.096  84.5  4.4619    4  307     21.0
# 15  0.62739  0.0   8.14     0  0.538  5.834  56.5  4.4986    4  307     21.0
# 16  1.05393  0.0   8.14     0  0.538  5.935  29.3  4.4986    4  307     21.0
# 17  0.78420  0.0   8.14     0  0.538  5.990  81.7  4.2579    4  307     21.0
# 18  0.80271  0.0   8.14     0  0.538  5.456  36.6  3.7965    4  307     21.0
# 19  0.72580  0.0   8.14     0  0.538  5.727  69.5  3.7965    4  307     21.0
# 20  1.25179  0.0   8.14     0  0.538  5.570  98.1  3.7979    4  307     21.0
# 21  0.85204  0.0   8.14     0  0.538  5.965  89.2  4.0123    4  307     21.0
# 22  1.23247  0.0   8.14     0  0.538  6.142  91.7  3.9769    4  307     21.0
#
#     LSTAT  MEDV
# 13   8.26  20.4
# 14  10.26  18.2
# 15   8.47  19.9
# 16   6.58  23.1
# 17  14.67  17.5
# 18  11.69  20.2
# ...

# %%
Bhousing3.shape
# Out:
# (55, 13)

# %%
Bhousing3
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 13   0.62976  0.0   8.14     0  0.538  5.949   61.8  4.7075    4  307
# 14   0.63796  0.0   8.14     0  0.538  6.096   84.5  4.4619    4  307
# 15   0.62739  0.0   8.14     0  0.538  5.834   56.5  4.4986    4  307
# 16   1.05393  0.0   8.14     0  0.538  5.935   29.3  4.4986    4  307
# 17   0.78420  0.0   8.14     0  0.538  5.990   81.7  4.2579    4  307
# 18   0.80271  0.0   8.14     0  0.538  5.456   36.6  3.7965    4  307
# 19   0.72580  0.0   8.14     0  0.538  5.727   69.5  3.7965    4  307
# 20   1.25179  0.0   8.14     0  0.538  5.570   98.1  3.7979    4  307
# 21   0.85204  0.0   8.14     0  0.538  5.965   89.2  4.0123    4  307
# 22   1.23247  0.0   8.14     0  0.538  6.142   91.7  3.9769    4  307
# 23   0.98843  0.0   8.14     0  0.538  5.813  100.0  4.0952    4  307
# 24   0.75026  0.0   8.14     0  0.538  5.924   94.1  4.3996    4  307
# ...

# %%
Bhousing.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   60.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.5
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2
# ...

# %%
import numpy as np

# %%
Bhousing['Log_AGE']=np.log(Bhousing.AGE)

# %%
Bhousing.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   60.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#    LSTAT  MEDV   Log_AGE
# 0   4.98  24.0  4.177459
# 1   9.14  21.5  4.368181
# 2   4.03  34.7  4.112512
# ...

# %%
del Bhousing['Log_AGE']

# %%
Bhousing.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   60.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.5
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2
# ...

# %%
Bhousing.rename(columns={'ZN':'ZONE'},inplace=True)

# %%
Bhousing.head(10)
# Out:
#       CRIM  ZONE  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   60.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.5
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(Bhousing['AGE'])
plt.show()

# %%
plt.hist(Bhousing['AGE'],rwidth=0.7,color='purple',orientation='horizontal')
plt.xlabel('Average Age of Houses')
plt.ylabel('# of Towns')
plt.title('Distribution of House Age')
plt.show()

# %%
plt.boxplot([Bhousing['MEDV'],Bhousing.LSTAT])
plt.title('Boxplot on MEDV and LSTAT')

plt.show()

# %%
plt.boxplot(Bhousing['CRIM'])
plt.title('Boxplot on Crime')
plt.ylim(0,12)
plt.show()

# %%
plt.scatter(Bhousing['MEDV'],Bhousing['RM'],color='crimson')
plt.xlabel('Median House Price')
plt.ylabel('Rooms')
plt.show()

# %%
plt.scatter(Bhousing['CRIM'],Bhousing['RM'],color='crimson')
plt.xlabel('Median House Price')
plt.ylabel('Rooms')
plt.show()

# %%
corrMatrix=Bhousing.corr()
corrMatrix.round(2)
# Out:
#          CRIM  ZONE  INDUS  CHAS   NOX    RM   AGE   DIS   RAD   TAX  PTRATIO  \
# CRIM     1.00 -0.20   0.41 -0.06  0.42 -0.22  0.35 -0.38  0.63  0.58     0.29
# ZONE    -0.20  1.00  -0.53 -0.04 -0.52  0.31 -0.57  0.66 -0.31 -0.31    -0.39
# INDUS    0.41 -0.53   1.00  0.06  0.76 -0.39  0.64 -0.71  0.60  0.72     0.38
# CHAS    -0.06 -0.04   0.06  1.00  0.09  0.09  0.09 -0.10 -0.01 -0.04    -0.12
# NOX      0.42 -0.52   0.76  0.09  1.00 -0.30  0.73 -0.77  0.61  0.67     0.19
# RM      -0.22  0.31  -0.39  0.09 -0.30  1.00 -0.24  0.21 -0.21 -0.29    -0.36
# AGE      0.35 -0.57   0.64  0.09  0.73 -0.24  1.00 -0.75  0.46  0.51     0.26
# DIS     -0.38  0.66  -0.71 -0.10 -0.77  0.21 -0.75  1.00 -0.49 -0.53    -0.23
# RAD      0.63 -0.31   0.60 -0.01  0.61 -0.21  0.46 -0.49  1.00  0.91     0.46
# TAX      0.58 -0.31   0.72 -0.04  0.67 -0.29  0.51 -0.53  0.91  1.00     0.46
# PTRATIO  0.29 -0.39   0.38 -0.12  0.19 -0.36  0.26 -0.23  0.46  0.46     1.00
# ...

# %%
plt.scatter(Bhousing['RAD'],Bhousing['TAX'],color='crimson')

plt.show()

# %%
plt.scatter(Bhousing['MEDV'],Bhousing['CRIM'],color='crimson')
plt.xlabel('Median House Price')
plt.ylabel('Crime')
plt.yscale('log')
plt.show()

# %%
plt.pie([40,60])
plt.show()

# %%
Bhousing['CHAS'].value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
size=[471,35]
plt.pie(size,labels=['Not Close','Close'],autopct='%1.1f%%',startangle=90)
plt.title('Proportion of CHAS')
plt.show()

# %%
size=[200,100,50]
plt.pie(size,labels=['IS','MKT','MGMT'],autopct='%1.1f%%',startangle=90)
plt.title('Proportion of CHAS')
plt.show()

# %%
Weather=pd.read_csv('C:/Users/jonat/OneDrive/Desktop/TTU Stuff/Fall/Big Data Strat/NoteBookFiles/Module 6/Chicago Weather.csv')
Weather
# Out:
#    Month   Temp_max   Temp_min   Temp_avg  Precipitation  Snow depth
# 0    Jan  28.580645  12.580645  20.580645       0.035000    2.354839
# 1    Feb  42.214286  25.500000  33.857143       0.159583    0.571429
# 2    Mar  49.064516  32.354839  40.709677       0.136667    0.096774
# 3    Apr  55.133333  38.933333  47.033333       0.212400    0.000000
# 4    May  72.225806  55.225806  63.725806       0.138800    0.000000
# 5    Jun  82.566667  61.866667  72.216667       0.095000    0.000000
# 6    Jul  83.516129  67.000000  75.258065       0.204545    0.000000
# 7    Aug  83.032258  65.677419  74.354839       0.085417    0.000000
# 8    Sep  75.966667  58.800000  67.383333       0.081481    0.000000
# 9    Oct  63.903226  44.161290  54.032258       0.059286    0.000000
# 10   Nov  51.666667  35.100000  43.383333       0.034400    0.033333
# 11   Dec  35.709677  22.516129  29.112903       0.093913    0.225806

# %%
plt.plot(Weather.Month,Weather.Temp_max,marker='v',color='crimson')
plt.plot(Weather.Month,Weather.Temp_avg,marker='o',color='green')
plt.plot(Weather.Month,Weather.Temp_min,marker='x',color='blue',linestyle='--')
plt.title('Weather in Chicago (2022)')
plt.xlabel('Months')
plt.ylabel('Temperature(F)')
plt.show()

# %%
fix,ax=plt.subplots()
ax.bar(Weather.Month,Weather.Precipitation)
ax.set_ylabel('Precipiration(inch)')
ax.set_title('Weather in Chicago (2022)')
ax2=ax.twinx()
ax2.plot(Weather.Month,Weather.Temp_avg, marker='o',color="red")
ax2.set_xlabel('Month')
ax2.set_ylabel('Temperature(F)')
# Out:
# Text(0, 0.5, 'Temperature(F)')

# %%
Covid=pd.read_csv('C:/Users/jonat/OneDrive/Desktop/TTU Stuff/Fall/Big Data Strat/NoteBookFiles/Module 6/Covid-19_month.csv')
Covid
# Out:
#    Month    Cases  Deaths
# 0      1        7       0
# 1      2       58       0
# 2      3   188411    4288
# 3      4   887343   58851
# 4      5   723578   41104
# 5      6   854080   23066
# 6      7  1918317   26336
# 7      8  1473553   29392
# 8      9   702164   14838

# %%
fix,ax=plt.subplots()
ax.bar(Covid.Month,Covid.Cases)
ax.set_ylabel('Positive Cases')
ax.set_title('Covid Trend in 2020')
ax2=ax.twinx()
ax2.plot(Covid.Month,Covid.Deaths,color="red")
ax2.set_xlabel('Month')
ax2.set_ylabel('Deaths')
# Out:
# Text(0, 0.5, 'Deaths')

# %%
categories = ['Programming', 'Critical Thinking', 'Analytical Skills', 'Communication','Stupidity','Cringe']
categories = [*categories, categories[0]]
My_ability = [1, 1, 1, 1, 5,5]
Others = [3,3,4,3,3,3]
RCOBA = [2,3,3,4,3,3]
My_ability = [*My_ability, My_ability[0]]
Others = [*Others, Others[0]]
RCOBA = [*RCOBA, RCOBA[0]]
label_loc = np.linspace(start=0, stop=2 * np.pi, num=len(My_ability))
plt.figure(figsize=(4, 4))
plt.subplot(polar=True)
plt.plot(label_loc, My_ability, label='My Abilities')
plt.plot(label_loc, Others, label='MSDS Average')
plt.plot(label_loc, RCOBA, label='RCOBA Average')
plt.title('My Abilities vs. Others')
lines, labels = plt.thetagrids(np.degrees(label_loc), labels=categories)
plt.legend(loc='center')
plt.show()

# %%
Bhousing.to_csv('C:/Users/jonat/OneDrive/Desktop/TTU Stuff/Fall/Big Data Strat/NoteBookFiles/Module 6/Bhousing_New.csv')

# %%
Orders=pd.read_csv('C:/Users/jonat/OneDrive/Desktop/TTU Stuff/Fall/Big Data Strat/NoteBookFiles/Module 6/Orders.csv')

Returns=pd.read_csv('C:/Users/jonat/OneDrive/Desktop/TTU Stuff/Fall/Big Data Strat/NoteBookFiles/Module 6/Returns.csv')

People=pd.read_csv('C:/Users/jonat/OneDrive/Desktop/TTU Stuff/Fall/Big Data Strat/NoteBookFiles/Module 6/People.csv')
# Out:
#               Person   Region
# 0      Anna Andreadi     West
# 1        Chuck Magee     East
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South

# %%
Orders_Returns_inner=Orders.merge(Returns,on='Order_ID')

# %%
Orders_Returns_inner.shape
# Out:
# (800, 22)

# %%
Orders_Returns_left=Orders.merge(Returns,on='Order_ID',how='left')

# %%
Orders_Returns_left.shape
# Out:
# (9994, 22)

# %%
Orders_Returns_right=Orders.merge(Returns,on='Order_ID',how='right')

# %%
Orders_Returns_right.shape
# Out:
# (800, 22)

# %%
Orders_Returns_outer=Orders.merge(Returns,on='Order_ID',how='outer')

# %%
Orders_Returns_outer.shape
# Out:
# (9994, 22)

# %%
People.head(10)
# Out:
#               Person   Region
# 0      Anna Andreadi     West
# 1        Chuck Magee     East
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South

# %%
Order_People=Orders.merge(People,on='Region',how='left')
Order_People.head(5)
# Out:
#    Row ID        Order_ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
Order_People.shape
# Out:
# (9994, 22)

# %%
file202303=pd.read_csv('C:/Users/jonat/OneDrive/Desktop/TTU Stuff/Fall/Big Data Strat/NoteBookFiles/Module 6/202303-divvy-tripdata(1).csv')

file202304=pd.read_csv('C:/Users/jonat/OneDrive/Desktop/TTU Stuff/Fall/Big Data Strat/NoteBookFiles/Module 6/202304-divvy-tripdata(1).csv')

# %%
merged=pd.concat([file202303,file202304])
merged.shape
# Out:
# (685268, 13)
